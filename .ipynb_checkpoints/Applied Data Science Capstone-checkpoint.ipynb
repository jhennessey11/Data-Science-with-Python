# %% [markdown]
# # Boston Neighborhoods Analysis

# %% [markdown]
# ## Gather Neighborhood Data, Clean Data, and Visualize Data

# %% [markdown]
# ### Import Relevant Libraries

# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook

# %% [markdown]
# ### Get data from excel file and load into a df

# %%
wb = load_workbook(filename='Boston Neighborhood Coordinates.xlsx', read_only=True)
ws = wb.active
col_names = [ws["A1"].value, ws["B1"].value, ws["C1"].value, ws["D1"].value]
header = np.array(col_names)

df = pd.DataFrame(ws.values, columns=header)
wb.close()

# %% [markdown]
# ### Clean Data

# %%
df = df.drop(['Zip Code'], axis=1)
df = df.drop([0])
df.set_index('Neighborhood', inplace=True)

# %%
df
# Out:
#                            Latitude Longitude
# Neighborhood
# Chinatown/Leather District  42.3515  -71.0602
# West End                    42.3653  -71.0646
# South End                   42.3378  -71.0706
# Roxbury                     42.3218  -71.0884
# Mission Hill                42.3319  -71.0988
# Mattapan                    42.2771  -71.0914
# South Boston                42.3365  -71.0349
# East Boston                 42.3745   -71.032
# Charlestown                 42.3795  -71.0646
# Jamaica Plain               42.3097  -71.1151
# Roslindale                  42.2832   -71.127
# West Roxbury                42.2798  -71.1627
# Allston                     42.3493    -71.13
# Brighton                      42.35   -71.158
# Hyde Park                   42.2528    -71.13
# North Cambridge             42.3933  -71.1345
# Brookline Village           42.3328  -71.1389
# Chestnut Hill               42.3278  -71.1627
# Downtown                    42.3573  -71.0562
# North End                   42.3646  -71.0534
# Beacon Hill                 42.3598  -71.0678
# Back Bay                    42.3515  -71.0805
# Dorchester                  42.2981  -71.0625
# Harvard Square              42.3725  -71.1202
# East Cambridge              42.3677   -71.081
# Fenway/Kenmore              42.3441  -71.0957
# Porter Square               42.3894  -71.1194
# West Cambridge               42.377  -71.1359
# Inman Square                42.3734  -71.0982
# Central Square              42.3651  -71.1034
# Davis Square                42.3963  -71.1222
# Winter Hill                 42.3909  -71.0958
# Assembly Square             42.3931  -71.0804
# Seaport                     42.3492  -71.0415

# %% [markdown]
# ## Create Map of Neighborhoods

# %%
import folium # map rendering library

# %%
# create map of Boston using latitude and longitude values
map_Boston = folium.Map(location=[42.3261, -71.07], zoom_start=12)

# add markers to map
for lat, lng, neighborhood in zip(df['Latitude'], df['Longitude'], df.index):
    label = f'{neighborhood}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Boston)
    
    folium.Circle([lat, lng],
                    radius=1000
                   ).add_to(map_Boston)
    
map_Boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Get Venue Data, Clean Data, and Visualize Data

# %%
import requests
import json # library to handle JSON files

# %%
CLIENT_ID = 'GKVJ5KSFU1RD00P24CV5JT2XSARMWSONFYRMLT2EK2IJFEBW'
CLIENT_SECRET = 'SSJALJ4S5QXDNQBZMNUNFBE1XMVQZETMJWU1JDXE2VWK2PZL'
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# ### Function that extracts the category of the venue

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ### Function that gets venues within a given radius of the Neighborhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        LIMIT = 1000
        
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        r = requests.get(url)
        print(r.status_code)
        results = r.json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
Boston_venues = getNearbyVenues(names=df.index, latitudes=df['Latitude'], longitudes=df['Longitude'], radius=1000)
# Out:
# Chinatown/Leather District
# 200
# West End
# 200
# South End
# 200
# Roxbury
# 200
# Mission Hill
# 200
# Mattapan
# 200
# South Boston
# 200
# East Boston
# 200
# Charlestown
# 200
# Jamaica Plain
# 200
# Roslindale
# 200
# West Roxbury
# 200
# Allston
# 200
# Brighton
# 200
# Hyde Park
# 200
# North Cambridge
# 200
# Brookline Village
# 200
# Chestnut Hill
# 200
# Downtown
# 200
# North End
# 200
# Beacon Hill
# 200
# Back Bay
# 200
# Dorchester
# 200
# Harvard Square
# 200
# East Cambridge
# 200
# Fenway/Kenmore
# 200
# Porter Square
# 200
# West Cambridge
# 200
# Inman Square
# 200
# Central Square
# 200
# Davis Square
# 200
# Winter Hill
# 200
# Assembly Square
# 200
# Seaport
# 200

# %% [markdown]
# ### Boston's Neighborhoods with Venues

# %%
print(Boston_venues.shape)
    
Boston_venues.nunique()
# Out:
# (2563, 7)
# Neighborhood                34
# Neighborhood Latitude       34
# Neighborhood Longitude      31
# Venue                     1908
# Venue Latitude            2157
# Venue Longitude           2158
# Venue Category             291
# dtype: int64

# %%
Boston_venues.head()
# Out:
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Chinatown/Leather District                42.3515                -71.0602
# 1  Chinatown/Leather District                42.3515                -71.0602
# 2  Chinatown/Leather District                42.3515                -71.0602
# 3  Chinatown/Leather District                42.3515                -71.0602
# 4  Chinatown/Leather District                42.3515                -71.0602
#
#                              Venue  Venue Latitude  Venue Longitude  \
# 0                 Gracenote Coffee       42.351657       -71.058204
# 1                        Shabu Zen       42.350922       -71.060942
# 2  Hostelling International Boston       42.351084       -71.063398
# 3                 Barry's Bootcamp       42.354010       -71.059776
# 4              Tatte Bakery & Cafe       42.353111       -71.057117
#
#          Venue Category
# 0           Coffee Shop
# 1      Asian Restaurant
# 2                Hostel
# 3  Gym / Fitness Center
# 4                Bakery

# %% [markdown]
# ### Create Excel File with total venue counts per category

# %%
Venue_cat_count = Boston_venues.groupby('Venue Category').count()
Venue_cat_count.rename(columns={'Venue': 'Count'}, inplace=True)
Venue_cat_count = pd.DataFrame(Venue_cat_count['Count'], Venue_cat_count.index)
Venue_cat_count.to_excel('Venue_Category_Counts.xlsx')
Venue_cat_count.sort_values('Count', ascending=False)
# Out:
#                     Count
# Venue Category
# Pizza Place            94
# Park                   92
# Coffee Shop            86
# Italian Restaurant     80
# Bakery                 66
# ...                   ...
# Eye Doctor              1
# Field                   1
# Food Service            1
# Pilates Studio          1
# ATM                     1
#
# [291 rows x 1 columns]

# %% [markdown]
# ### Create Excel File with total venue counts per neighborhood

# %%
Venue_per_hood = Boston_venues.groupby('Neighborhood').count()
Venue_per_hood.rename(columns={'Venue': 'Count'}, inplace=True)
Venue_per_hood = pd.DataFrame(Venue_per_hood['Count'], Venue_per_hood.index)
Venue_per_hood.to_excel('Venue_Per_Hood.xlsx')
Venue_per_hood.sort_values('Count', ascending=False)
# Out:
#                             Count
# Neighborhood
# Allston                       100
# North End                     100
# Inman Square                  100
# Assembly Square               100
# Harvard Square                100
# Fenway/Kenmore                100
# East Cambridge                100
# Downtown                      100
# Seaport                       100
# Davis Square                  100
# Chinatown/Leather District    100
# South End                     100
# Central Square                100
# West End                      100
# Beacon Hill                   100
# Back Bay                      100
# Porter Square                 100
# East Boston                    92
# Brighton                       76
# South Boston                   67
# Winter Hill                    67
# Chestnut Hill                  61
# Jamaica Plain                  59
# Mission Hill                   57
# Roslindale                     52
# Brookline Village              50
# West Roxbury                   46
# Dorchester                     41
# Charlestown                    40
# Hyde Park                      38
# Mattapan                       34
# North Cambridge                28
# West Cambridge                 28
# Roxbury                        27

# %% [markdown]
# ### Create dummy variables to proportion venue categories for each neighborhood

# %%
# one hot encoding
Boston_onehot = pd.get_dummies(Boston_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Boston_onehot['Neighborhood'] = Boston_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [Boston_onehot.columns[-1]] + list(Boston_onehot.columns[:-1])
Boston_onehot = Boston_onehot[fixed_columns]

# %%
Boston_grouped = Boston_onehot.groupby('Neighborhood').mean().reset_index()
Boston_grouped
# Out:
#                   Neighborhood  Yoga Studio       ATM  Accessories Store  \
# 0                      Allston     0.010000  0.000000           0.000000
# 1              Assembly Square     0.000000  0.000000           0.000000
# 2                     Back Bay     0.010000  0.000000           0.000000
# 3                  Beacon Hill     0.010000  0.000000           0.000000
# 4                     Brighton     0.000000  0.000000           0.000000
# 5            Brookline Village     0.000000  0.000000           0.000000
# 6               Central Square     0.020000  0.000000           0.000000
# 7                  Charlestown     0.025000  0.000000           0.000000
# 8                Chestnut Hill     0.000000  0.000000           0.000000
# 9   Chinatown/Leather District     0.000000  0.000000           0.000000
# 10                Davis Square     0.020000  0.000000           0.000000
# 11                  Dorchester     0.000000  0.000000           0.000000
# 12                    Downtown     0.020000  0.000000           0.000000
# 13                 East Boston     0.000000  0.000000           0.000000
# 14              East Cambridge     0.000000  0.000000           0.000000
# 15              Fenway/Kenmore     0.000000  0.000000           0.000000
# 16             Harvard Square      0.010000  0.000000           0.000000
# 17                   Hyde Park     0.026316  0.026316           0.000000
# 18                Inman Square     0.000000  0.000000           0.000000
# 19               Jamaica Plain     0.033898  0.000000           0.033898
# 20                    Mattapan     0.000000  0.000000           0.000000
# 21                Mission Hill     0.000000  0.000000           0.000000
# 22            North Cambridge      0.000000  0.000000           0.000000
# 23                   North End     0.020000  0.000000           0.000000
# 24               Porter Square     0.020000  0.000000           0.000000
# 25                  Roslindale     0.038462  0.000000           0.000000
# 26                     Roxbury     0.000000  0.000000           0.000000
# 27                     Seaport     0.000000  0.000000           0.000000
# 28                South Boston     0.000000  0.000000           0.000000
# 29                   South End     0.010000  0.000000           0.010000
# 30              West Cambridge     0.000000  0.000000           0.000000
# 31                    West End     0.020000  0.000000           0.000000
# 32                West Roxbury     0.000000  0.000000           0.000000
# 33                 Winter Hill     0.000000  0.000000           0.000000
#
#     Afghan Restaurant  African Restaurant   Airport  Airport Service  \
# 0                0.00            0.000000  0.000000          0.00000
# 1                0.00            0.000000  0.000000          0.00000
# 2                0.00            0.000000  0.000000          0.00000
# 3                0.00            0.000000  0.000000          0.00000
# 4                0.00            0.000000  0.000000          0.00000
# 5                0.00            0.000000  0.000000          0.00000
# 6                0.00            0.000000  0.000000          0.00000
# 7                0.00            0.000000  0.000000          0.00000
# 8                0.00            0.000000  0.000000          0.00000
# 9                0.00            0.000000  0.000000          0.00000
# 10               0.00            0.000000  0.000000          0.00000
# 11               0.00            0.000000  0.000000          0.00000
# 12               0.00            0.000000  0.000000          0.00000
# 1              Restaurant      Sporting Goods Shop        American Restaurant
# 2      Italian Restaurant              Coffee Shop                        Gym
# 3              Steakhouse        French Restaurant        American Restaurant
# 4                  Bakery                      Pub              Grocery Store
# 5             Pizza Place             Tennis Court               Liquor Store
# 6                  Bakery  New American Restaurant                        Bar
# 7              Donut Shop            Grocery Store                       Café
# 8       Mobile Phone Shop                 Boutique             Baseball Field
# 9        Asian Restaurant                     Park                    Theater
# 10                   Café         Ramen Restaurant                Pizza Place
# 11           Liquor Store           Discount Store                 Donut Shop
# 12         Sandwich Place            Historic Site        American Restaurant
# 13            Pizza Place        Convenience Store             Sandwich Place
# 14            Art Gallery              Pizza Place   Mediterranean Restaurant
# 15            Coffee Shop             Burger Joint                     Bakery
# 16                   Park  New American Restaurant                  Gastropub
# 17          Grocery Store                      Gym               Skating Rink
# 18                 Bakery                      Pub      Portuguese Restaurant
# 19         Ice Cream Shop              Pizza Place                        Pub
# 20               Pharmacy                     Park              Event Service
# 21                   Park           Sandwich Place                       Café
# 22  Sri Lankan Restaurant                   Office  Middle Eastern Restaurant
# 23                  Hotel                   Bakery                Coffee Shop
# 24    American Restaurant                Gift Shop                     Bakery
# 25     Chinese Restaurant                      Bar             Sandwich Place
# 26    American Restaurant                     Food   Bike Rental / Bike Share
# 27     Italian Restaurant               Restaurant           Asian Restaurant
# 28            Pizza Place                    Beach    New American Restaurant
# 29            Coffee Shop        French Restaurant         Mexican Restaurant
# 30              BBQ Joint               Restaurant                 Shoe Store
# 31                   Park       Seafood Restaurant              Historic Site
# 32               Pharmacy            Train Station          Convenience Store
# 33                    Spa    General Entertainment                       Park
#
#               8th Most Common Venue 9th Most Common Venue  ...  \
# 0                       Coffee Shop            Donut Shop  ...
# 1                               Gym  Brazilian Restaurant  ...
# 2                            Bakery             Wine Shop  ...
# 3                Seafood Restaurant                  Park  ...
# 4                        Donut Shop        Sandwich Place  ...
# 5                         Gastropub            Donut Shop  ...
# 6                       Yoga Studio                Lounge  ...
# 7                       Coffee Shop           Yoga Studio  ...
# 8            Furniture / Home Store          Tennis Court  ...
# 9             Performing Arts Venue                  Café  ...
# 10                     Liquor Store           Yoga Studio  ...
# 11  Southern / Soul Food Restaurant                Market  ...
# 12               Seafood Restaurant                Bakery  ...
# 13                       Donut Shop                  Café  ...
# 14                   Science Museum                  Café  ...
# 15           Furniture / Home Store      Sushi Restaurant  ...
# 16                      Record Shop                   Spa  ...
# 17                      Yoga Studio           Event Space  ...
# 18                    Grocery Store           Pizza Place  ...
# 19                       Donut Shop    Seafood Restaurant  ...
# 20                       Nail Salon                  Food  ...
# 21                              Gym    Falafel Restaurant  ...
# 22               Mexican Restaurant            Food Truck  ...
# 23                   Sandwich Place         Historic Site  ...
# 24                              Bar    Mexican Restaurant  ...
# 25                           Bakery           Coffee Shop  ...
# 26                           Museum                  Café  ...
# 27                          Brewery                   Gym  ...
# 28                            Diner                   Pub  ...
# 29                             Café  Gym / Fitness Center  ...
# 30                   Baseball Field                Lounge  ...
# 31                   Science Museum           Coffee Shop  ...
# 32                   Discount Store         Grocery Store  ...
# 33          New American Restaurant              Bus Stop  ...
#
#        11th Most Common Venue 12th Most Common Venue   13th Most Common Venue  \
# 0        Gym / Fitness Center     Falafel Restaurant       Seafood Restaurant
# 1              Sandwich Place                   Café               Steakhouse
# 2    Mediterranean Restaurant          Shopping Mall                    Plaza
# 3              Scenic Lookout                    Bar            Boat or Ferry
# 4             Thai Restaurant       Sushi Restaurant                Pet Store
# 5          Chinese Restaurant     Salon / Barbershop                     Bank
# 6                         Pub            Pizza Place             Cocktail Bar
# 7                     Theater           Liquor Store                      Bar
# 8                        Bank   Gym / Fitness Center      American Restaurant
# 9                         Spa      French Restaurant                    Hotel
# 10  Middle Eastern Restaurant         Ice Cream Shop               Hobby Shop
# 11             Baseball Field            Supermarket            Metro Station
# 12              Deli / Bodega       Greek Restaurant              Pizza Place
# 13         Chinese Restaurant          Metro Station             Liquor Store
# 14                     Bakery     Chinese Restaurant             Liquor Store
# 15            Thai Restaurant                    Gym                   Garden
# 16                      Plaza            Coffee Shop       Mexican Restaurant
# 17                        Bar       Storage Facility     Fast Food Restaurant
# 18   Mediterranean Restaurant         Sandwich Place         Tapas Restaurant
# 19                Art Gallery              Bookstore      American Restaurant
# 20                 Shoe Store           Liquor Store           Scenic Lookout
# 21         Italian Restaurant            Coffee Shop             Liquor Store
# 22            Organic Grocery                    Bar       Seafood Restaurant
# 23                Beer Garden            Yoga Studio         Greek Restaurant
# 24            Thai Restaurant     Chinese Restaurant            Deli / Bodega
# 25                       Park          Grocery Store      American Restaurant
# 26       Caribbean Restaurant          Grocery Store                    Diner
# 27                Salad Place                   Park  New American Restaurant
# 28                        Bar                  Track               Sports Bar
# 29                  Gastropub            Art Gallery          Thai Restaurant
# 30                     Bakery            Cheese Shop       Chinese Restaurant
# 31              Deli / Bodega     Mexican Restaurant        French Restaurant
# 32                Coffee Shop                  Diner           Clothing Store
# 33               Liquor Store               Pharmacy           Ice Cream Shop
#
#     14th Most Common Venue           15th Most Common Venue  \
# 0               Taco Place                              Gym
# 1                      Bar                      Pizza Place
# 2              Salad Place                    Jewelry Store
# 3           Science Museum                Outdoor Sculpture
# 4                      Bar                      Coffee Shop
# 5                      Bar                         Pharmacy
# 6         Sushi Restaurant                             Park
# 7            Metro Station               Seafood Restaurant
# 8            Grocery Store                         Pharmacy
# 9       Seafood Restaurant                  Bubble Tea Shop
# 10        Greek Restaurant                     Gourmet Shop
# 11    Fast Food Restaurant                              Pub
# 12                Tea Room                       Restaurant
# 13        Airport Terminal                         Pharmacy
# 14          Lingerie Store                              Bar
# 15          Clothing Store                       Art Museum
# 16             Music Venue                          Theater
# 17              Skate Park                          Theater
# 18      Italian Restaurant                Indian Restaurant
# 19       Accessories Store               Mexican Restaurant
# 20               BBQ Joint  Southern / Soul Food Restaurant
# 21  Furniture / Home Store                   Massage Studio
# 22                Dive Bar                     Liquor Store
# 23     American Restaurant                    Boat or Ferry
# 24      Italian Restaurant                      Yoga Studio
# 25      Mexican Restaurant                             Pool
# 26        Department Store                            Plaza
# 27          Clothing Store                French Restaurant
# 28              Donut Shop              American Restaurant
# 29          Sandwich Place                           Bakery
# 30                    Park                      Auto Garage
# 31            Gourmet Shop                    Grocery Store
# 32      Salon / Barbershop                   Sandwich Place
# 33         Harbor / Marina               Falafel Restaurant
#
#         16th Most Common Venue     17th Most Common Venue  \
# 0                    Gastropub        Japanese Restaurant
# 1                         Park     Furniture / Home Store
# 2               Ice Cream Shop           Sushi Restaurant
# 3                   Restaurant                    Theater
# 4                     Pharmacy           Greek Restaurant
# 5             Sushi Restaurant                   Platform
# 6                    Nightclub                   Tea Room
# 7                         Park                 Skate Park
# 8               Breakfast Spot          French Restaurant
# 9             Sushi Restaurant                Salad Place
# 10             Thai Restaurant                  Gift Shop
# 11              Breakfast Spot        Fried Chicken Joint
# 12                        Café                Salad Place
# 13                      Bakery                Art Gallery
# 14        Gym / Fitness Center             Sandwich Place
# 15   Middle Eastern Restaurant         Mexican Restaurant
# 16                  Food Truck             Ice Cream Shop
# 17                  Donut Shop           Business Service
# 18              Ice Cream Shop        Peruvian Restaurant
# 19                 Record Shop                    Library
# 20  Construction & Landscaping              Train Station
# 21               Metro Station                  Bookstore
# 22          Chinese Restaurant                     Bistro
# 23          Mexican Restaurant              Grocery Store
# 24               Burrito Place                Pizza Place
# 25                    Bus Line                Cheese Shop
# 26              Cosmetics Shop        Fried Chicken Joint
# 27                         Bar                     Bakery
# 28              Breakfast Spot     Furniture / Home Store
# 29                         Bar           Asian Restaurant
# 30          Athletics & Sports       Other Great Outdoors
# 31                         Bar             Sandwich Place
# 32                        Park                       Café
# 33              Farmers Market  Cajun / Creole Restaurant
#
#       18th Most Common Venue         19th Most Common Venue  \
# 0                  Gift Shop                      Rock Club
# 1         Italian Restaurant                 Ice Cream Shop
# 2                      Hotel           Gym / Fitness Center
# 3                     Market                      Hotel Bar
# 4                       Park                Supplement Shop
# 5          French Restaurant                     Playground
# 6                  Bookstore           Gym / Fitness Center
# 7        Monument / Landmark            Moroccan Restaurant
# 8                     Forest                     Food Truck
# 9              Historic Site                       Tea Room
# 10             Burrito Place            American Restaurant
# 11        Seafood Restaurant                 Sandwich Place
# 12            History Museum                     Steakhouse
# 13                   Airport           Brazilian Restaurant
# 14        Italian Restaurant          Vietnamese Restaurant
# 15                 Bookstore                    Pizza Place
# 16        Italian Restaurant  Vegetarian / Vegan Restaurant
# 17            Discount Store                 Sandwich Place
# 18   Comfort Food Restaurant                   Cocktail Bar
# 19              Liquor Store        New American Restaurant
# 20       American Restaurant                   Home Service
# 21                    Museum                   Soccer Field
# 22                       Gym                      Pet Store
# 23                  Boutique                     Ski Chalet
# 24         Indian Restaurant                     Poke Place
# 25            Ice Cream Shop              Indian Restaurant
# 26              Concert Hall             African Restaurant
# 27  Mediterranean Restaurant                 Scenic Lookout
# 28            Rental Service               Sushi Restaurant
# 29                 Gift Shop                        Dog Run
# 30          Sushi Restaurant                            Gym
# 31            Scenic Lookout             Salon / Barbershop
# 32                       Pub                    Event Space
# 33               Flower Shop            Sporting Goods Shop
#
#            20th Most Common Venue
# 0                            Café
# 1                     Video Store
# 2                      Steakhouse
# 3            Gym / Fitness Center
# 4                Storage Facility
# 5             Sporting Goods Shop
# 6                            Café
# 7                   Auto Workshop
# 8              Chinese Restaurant
# 9                    Burger Joint
# 10  Vegetarian / Vegan Restaurant
# 11            Rental Car Location
# 12               Sushi Restaurant
# 13                   Dessert Shop
# 14                      Hotel Bar
# 15                 Baseball Field
# 16                         Bakery
# 17                           Park
# 18  Vegetarian / Vegan Restaurant
# 19                      Speakeasy
# 20              Convenience Store
# 21                   Burger Joint
# 22                    Pizza Place
# 23                   Skating Rink
# 24                            Pub
# 25               Greek Restaurant
# 26           Gym / Fitness Center
# 27                     Art Museum
# 28                   Liquor Store
# 29                    Pizza Place
# 30                    Coffee Shop
# 31                    Salad Place
# 32                           Bank
# 33                Meze Restaurant
#
# [34 rows x 21 columns]

# %% [markdown]
# ## Create Relevant Functions

# %% [markdown]
# ### df_style Function

# %%
def df_style(val):
    boolean = 0
    for item in match:
        if val == item:
            boolean = 1
        
    if boolean == 1:
        return 'font-weight: bold'
    else:
        return ''

# %% [markdown]
# ### Main_Score Function

# %%
def main_score(df):

    score = []
    j=0
    for row in df.itertuples():
        i=0 
        for item in zip(row):
            if item[0] == match[0]:
                if i <= 2:
                    score.append(1)
                elif i <= 4:
                    score.append(.9)
                elif i <= 6:
                    score.append(.75)
                elif i <= 11:
                    score.append(.5)
                elif i <= 16:
                    score.append(.33)
                elif i <= 21:
                    score.append(.2)
                else:
                    score.append(0)
            i=i+1
        j=j+1
        if j > len(score):
            score.append(0)
            
    df['Main Score'] = score
    df.sort_values(by=['Main Score'], ascending=False, inplace=True)

# %% [markdown]
# ### Match Function

# %%
def match_func(criterion):

    match = []
    for item in criterion:

        mask = neighborhoods_venues_sorted.applymap(lambda x: item in str(x))
        match_results = neighborhoods_venues_sorted[mask == True].dropna(how='all')

        for i in range(0,len(match_results.index)):
            results = []
            results = match_results.iloc[i,].unique()
            match.append(results[1])
            
    match = list(dict.fromkeys(match))
    return match

# %% [markdown]
# ### Match_Score Function

# %%
def match_score(df):

    num_match = []
    score = []

    for row in df.itertuples():
        i=0
        for item in zip(row):
            for crit in match:
                if item[0] == crit:
                    i=i+1
        num_match.append(i)
        score.append(i/5)
    df['Number of Matches'] = num_match
    df['Match Score'] = score
    df.sort_values(by=['Number of Matches'], ascending=False, inplace=True)

# %% [markdown]
# ### Total_Score Function

# %%
def total_score(df):
    tot_score = []
    rows = len(df.index)
    for i in range(0,rows):
        main_score = df.loc[df.index[i], 'Main Score']
        match_score = df.loc[df.index[i], 'Match Score']
        tot_score.append((main_score + match_score)/2)
    df['Total Score'] = tot_score
    df.sort_values(by=['Total Score'], ascending=False, inplace=True)

# %% [markdown]
# ## Run Analysis of Neighborhoods based on Criterion

# %% [markdown]
# ### Create df that includes Neighborhoods with PRIORITY criterion

# %%
criterion = ['Italian', 'Pizza', 'Ice Cream', 'Gym', 'Pub'] #First term is priority venue
match = []

mask = neighborhoods_venues_sorted.applymap(lambda x: criterion[0] in str(x))
search_priority = neighborhoods_venues_sorted[mask == True].dropna(how='all')

for i in range(0,len(search_priority.index)):
    results = []
    results = search_priority.iloc[i,].unique()
    match.insert(0, results[1])
match = list(dict.fromkeys(match))

search_priority = neighborhoods_venues_sorted.iloc[search_priority.index]
match = match_func(criterion)
main_score(search_priority)
match_score(search_priority)
total_score(search_priority)
    
i=0
for items in zip(search_priority['Neighborhood']):
    i=i+1
print(f"{i} Results Found!")

search_priority.style.applymap(df_style)
# Out:
# C:\Users\jhenn\anaconda3\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\jhenn\anaconda3\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\jhenn\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jhenn\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\jhenn\anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\jhenn\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jhenn\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# 19 Results Found!
# <style  type="text/css" >
#     #T_21e79cc2_a36f_11ea_bf34_d812652c170crow0_col1 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow0_col9 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow0_col20 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow1_col5 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow1_col7 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow1_col16 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow1_col19 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow2_col4 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow2_col11 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow2_col12 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow2_col19 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow3_col3 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow3_col5 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow3_col9 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow4_col1 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow4_col2 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow4_col18 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow5_col1 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow5_col4 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow6_col4 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow6_col10 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow6_col20 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow7_col4 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow7_col10 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow7_col14 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow7_col17 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow7_col20 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow8_col3 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow8_col13 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow9_col2 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow9_col19 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow10_col3 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow10_col5 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow11_col2 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow11_col3 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow12_col5 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow12_col9 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow13_col6 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow13_col9 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow13_col14 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow13_col16 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow14_col2 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow14_col10 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow14_col12 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow15_col8 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow15_col15 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow15_col18 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow15_col19 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow16_col4 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow16_col8 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow16_col11 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow17_col6 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow17_col16 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow17_col18 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow18_col4 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow18_col17 {
#             font-weight:  bold;
#         }    #T_21e79cc2_a36f_11ea_bf34_d812652c170crow18_col18 {
#             font-weight:  bold;
#         }</style><table id="T_21e79cc2_a36f_11ea_bf34_d812652c170c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Neighborhood</th>        <th class="col_heading level0 col1" >1st Most Common Venue</th>        <th class="col_heading level0 col2" >2nd Most Common Venue</th>        <th class="col_heading level0 col3" >3rd Most Common Venue</th>        <th class="col_heading level0 col4" >4th Most Common Venue</th>        <th class="col_heading level0 col5" >5th Most Common Venue</th>        <th class="col_heading level0 col6" >6th Most Common Venue</th>        <th class="col_heading level0 col7" >7th Most Common Venue</th>        <th class="col_heading level0 col8" >8th Most Common Venue</th>        <th class="col_heading level0 col9" >9th Most Common Venue</th>        <th class="col_heading level0 col10" >10th Most Common Venue</th>        <th class="col_heading level0 col11" >11th Most Common Venue</th>        <th class="col_heading level0 col12" >12th Most Common Venue</th>        <th class="col_heading level0 col13" >13th Most Common Venue</th>        <th class="col_heading level0 col14" >14th Most Common Venue</th>        <th class="col_heading level0 col15" >15th Most Common Venue</th>        <th class="col_heading level0 col16" >16th Most Common Venue</th>        <th class="col_heading level0 col17" >17th Most Common Venue</th>        <th class="col_heading level0 col18" >18th Most Common Venue</th>        <th class="col_heading level0 col19" >19th Most Common Venue</th>        <th class="col_heading level0 col20" >20th Most Common Venue</th>        <th class="col_heading level0 col21" >Main Score</th>        <th class="col_heading level0 col22" >Number of Matches</th>        <th class="col_heading level0 col23" >Match Score</th>        <th class="col_heading level0 col24" >Total Score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21e79cc2_a36f_11ea_bf34_d812652c170clevel0_row0" class="row_heading level0 row0" >29</th>
#                         <td id="T_21e79cc2_a36f_11ea_bf34_d812652c170crow0_col0" class="data row0 col0" >South End</td>
#                         <td id="T_21e79cc2_a36f_11ea_bf34_d812652c170crow0_col1" class="data row0 col1" >Italian Restaurant</td>
#                         <td id="T_21e79cc2_a36f_11ea_bf34_d812652c170crow0_col2" class="data row0 col2" >Wine Bar</td>
#                         <td id="T_21e79c

# %% [markdown]
# ### Create df that includes Neighborhoods with ALL criterion

# %%
search_perf = search_priority.loc[search_priority['Number of Matches'] == 5]

rows = len(search_perf.index)
print(f"{rows} Results Found!")

if rows == 0:
    print("Criterion too specific")

search_perf.style.applymap(df_style)
# Out:
# 1 Results Found!
# <style  type="text/css" >
#     #T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col4 {
#             font-weight:  bold;
#         }    #T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col10 {
#             font-weight:  bold;
#         }    #T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col14 {
#             font-weight:  bold;
#         }    #T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col17 {
#             font-weight:  bold;
#         }    #T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col20 {
#             font-weight:  bold;
#         }</style><table id="T_21ed0310_a36f_11ea_9d3d_d812652c170c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Neighborhood</th>        <th class="col_heading level0 col1" >1st Most Common Venue</th>        <th class="col_heading level0 col2" >2nd Most Common Venue</th>        <th class="col_heading level0 col3" >3rd Most Common Venue</th>        <th class="col_heading level0 col4" >4th Most Common Venue</th>        <th class="col_heading level0 col5" >5th Most Common Venue</th>        <th class="col_heading level0 col6" >6th Most Common Venue</th>        <th class="col_heading level0 col7" >7th Most Common Venue</th>        <th class="col_heading level0 col8" >8th Most Common Venue</th>        <th class="col_heading level0 col9" >9th Most Common Venue</th>        <th class="col_heading level0 col10" >10th Most Common Venue</th>        <th class="col_heading level0 col11" >11th Most Common Venue</th>        <th class="col_heading level0 col12" >12th Most Common Venue</th>        <th class="col_heading level0 col13" >13th Most Common Venue</th>        <th class="col_heading level0 col14" >14th Most Common Venue</th>        <th class="col_heading level0 col15" >15th Most Common Venue</th>        <th class="col_heading level0 col16" >16th Most Common Venue</th>        <th class="col_heading level0 col17" >17th Most Common Venue</th>        <th class="col_heading level0 col18" >18th Most Common Venue</th>        <th class="col_heading level0 col19" >19th Most Common Venue</th>        <th class="col_heading level0 col20" >20th Most Common Venue</th>        <th class="col_heading level0 col21" >Main Score</th>        <th class="col_heading level0 col22" >Number of Matches</th>        <th class="col_heading level0 col23" >Match Score</th>        <th class="col_heading level0 col24" >Total Score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21ed0310_a36f_11ea_9d3d_d812652c170clevel0_row0" class="row_heading level0 row0" >24</th>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col0" class="data row0 col0" >Porter Square</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col1" class="data row0 col1" >Park</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col2" class="data row0 col2" >Café</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col3" class="data row0 col3" >Japanese Restaurant</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col4" class="data row0 col4" >Ice Cream Shop</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col5" class="data row0 col5" >American Restaurant</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col6" class="data row0 col6" >Gift Shop</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col7" class="data row0 col7" >Bakery</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col8" class="data row0 col8" >Bar</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col9" class="data row0 col9" >Mexican Restaurant</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col10" class="data row0 col10" >Gym</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col11" class="data row0 col11" >Thai Restaurant</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col12" class="data row0 col12" >Chinese Restaurant</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col13" class="data row0 col13" >Deli / Bodega</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col14" class="data row0 col14" >Italian Restaurant</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col15" class="data row0 col15" >Yoga Studio</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col16" class="data row0 col16" >Burrito Place</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col17" class="data row0 col17" >Pizza Place</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col18" class="data row0 col18" >Indian Restaurant</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col19" class="data row0 col19" >Poke Place</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col20" class="data row0 col20" >Pub</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col21" class="data row0 col21" >0.330000</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col22" class="data row0 col22" >5</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col23" class="data row0 col23" >1.000000</td>
#                         <td id="T_21ed0310_a36f_11ea_9d3d_d812652c170crow0_col24" class="data row0 col24" >0.665000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Final Score Result for all Neighborhoods

# %%
criterion = ['Italian', 'Pizza', 'Ice Cream', 'Gym', 'Pub'] #First term is priority venue
match = match_func(criterion)
main_score(neighborhoods_venues_sorted)
match_score(neighborhoods_venues_sorted)
total_score(neighborhoods_venues_sorted)
neighborhoods_venues_sorted.style.applymap(df_style)
# Out:
# <style  type="text/css" >
#     #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow0_col1 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow0_col9 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow0_col20 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow1_col5 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow1_col7 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow1_col16 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow1_col19 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow2_col4 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow2_col11 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow2_col12 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow2_col19 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow3_col1 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow3_col2 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow3_col18 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow4_col3 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow4_col5 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow4_col9 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow5_col1 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow5_col4 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow6_col4 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow6_col10 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow6_col20 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow7_col4 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow7_col10 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow7_col14 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow7_col17 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow7_col20 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow8_col3 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow8_col5 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow9_col2 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow9_col3 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow10_col2 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow10_col19 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow11_col3 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow11_col13 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow12_col5 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow12_col9 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow13_col6 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow13_col9 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow13_col14 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow13_col16 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow14_col2 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow14_col10 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow14_col12 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow15_col8 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow15_col15 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow15_col18 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow15_col19 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow16_col4 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow16_col8 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow16_col11 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow17_col4 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow17_col17 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow17_col18 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow18_col6 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow18_col16 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow18_col18 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow19_col5 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow19_col10 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow19_col11 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow19_col15 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow20_col1 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow20_col10 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow20_col18 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow21_col5 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow21_col6 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow21_col7 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow22_col1 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow22_col13 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow23_col12 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow23_col19 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow24_col2 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow24_col15 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow25_col7 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow25_col12 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow26_col1 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow26_col6 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow27_col1 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow27_col6 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow28_col18 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow28_col20 {
#             font-weight:  bold;
#         }    #T_d72ad9fa_a372_11ea_a7f3_d812652c170crow29_col2 {
#             font-weight:  bold;
#         }    #T_d72ad

# %% [markdown]
# ## Map all Italian Restaurants in Boston

# %%
Boston_Italian = Boston_venues.loc[Boston_venues['Venue Category'] == 'Italian Restaurant']
Boston_Italian.drop(['Neighborhood Latitude', 'Neighborhood Longitude'], axis=1, inplace=True)
fixed_columns = [Boston_Italian.columns[1]] + list(Boston_Italian.columns[2:4]) + [Boston_Italian.columns[0]] + [Boston_Italian.columns[-1]]
Boston_Italian = Boston_Italian[fixed_columns]
# Out:
# C:\Users\jhenn\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
Boston_Italian
# Out:
#                             Venue  Venue Latitude  Venue Longitude  \
# 84        Maggiano's Little Italy       42.350966       -71.068695
# 111               Osteria Rustico       42.364397       -71.059870
# 121   Scampo at The Liberty Hotel       42.361937       -71.070513
# 124                        Grotto       42.359915       -71.062807
# 177                          Aria       42.363286       -71.055002
# ...                           ...             ...              ...
# 2498                    Sportello       42.350519       -71.048687
# 2522            Sapóre Ristorante       42.348126       -71.039863
# 2530               Buco Trattoria       42.349923       -71.049393
# 2536               Tuscan Kitchen       42.352829       -71.047298
# 2547            Strega Waterfront       42.353062       -71.045162
#
#                     Neighborhood      Venue Category
# 84    Chinatown/Leather District  Italian Restaurant
# 111                     West End  Italian Restaurant
# 121                     West End  Italian Restaurant
# 124                     West End  Italian Restaurant
# 177                     West End  Italian Restaurant
# ...                          ...                 ...
# 2498                     Seaport  Italian Restaurant
# 2522                     Seaport  Italian Restaurant
# 2530                     Seaport  Italian Restaurant
# 2536                     Seaport  Italian Restaurant
# 2547                     Seaport  Italian Restaurant
#
# [80 rows x 5 columns]

# %%
# create map of Boston using latitude and longitude values
map_Italian = folium.Map(location=[42.3261, -71.07], zoom_start=12)

# add Restaurant markers to map
for lat, lng, venue, neighborhood in zip(Boston_Italian['Venue Latitude'], Boston_Italian['Venue Longitude'], Boston_Italian['Venue'], Boston_Italian['Neighborhood']):
    label = f'{venue}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Italian)
    
# add Neighborhood markers to map
for lat, lng, neighborhood in zip(df['Latitude'], df['Longitude'], df.index):
    label = f'{neighborhood}'
    label = folium.Popup(label, parse_html=True)
    
    folium.Circle(
        [lat, lng],
        radius=1000,
        popup=label).add_to(map_Italian)
    
map_Italian
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Map Top Neighborhood

# %%
Top_Hood = Boston_venues.loc[Boston_venues['Neighborhood'] == neighborhoods_venues_sorted.iloc[0]['Neighborhood']]
Top_Hood
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 200    South End                42.3378                -71.0706
# 201    South End                42.3378                -71.0706
# 202    South End                42.3378                -71.0706
# 203    South End                42.3378                -71.0706
# 204    South End                42.3378                -71.0706
# ..           ...                    ...                     ...
# 295    South End                42.3378                -71.0706
# 296    South End                42.3378                -71.0706
# 297    South End                42.3378                -71.0706
# 298    South End                42.3378                -71.0706
# 299    South End                42.3378                -71.0706
#
#                       Venue  Venue Latitude  Venue Longitude  \
# 200                  Stella       42.339736       -71.072574
# 201             anoush’ella       42.338869       -71.073843
# 202     Flour Bakery & Cafe       42.338447       -71.074299
# 203             The Gallows       42.341262       -71.070135
# 204  Boston Flower Exchange       42.337819       -71.066743
# ..                      ...             ...              ...
# 295             Lion's Tail       42.344888       -71.063497
# 296     BURN Fitness Studio       42.341588       -71.080917
# 297           House of Siam       42.343157       -71.073138
# 298             Bar Mezzana       42.344562       -71.063560
# 299       Fuji at Ink Block       42.345096       -71.063528
#
#                Venue Category
# 200        Italian Restaurant
# 201  Mediterranean Restaurant
# 202                    Bakery
# 203                 Gastropub
# 204               Flower Shop
# ..                        ...
# 295                 Speakeasy
# 296                       Gym
# 297           Thai Restaurant
# 298        Italian Restaurant
# 299       Japanese Restaurant
#
# [100 rows x 7 columns]

# %%
# create map of Boston using latitude and longitude values
latitude = Top_Hood.iloc[0]['Neighborhood Latitude']
longitude = Top_Hood.iloc[0]['Neighborhood Longitude']
map_Top_Hood = folium.Map(location=[latitude, longitude], zoom_start=15)

# add Restaurant markers to map
for lat, lng, venue in zip(Top_Hood['Venue Latitude'], Top_Hood['Venue Longitude'], Top_Hood['Venue']):
    label = f'{venue}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Top_Hood)
    
# add Neighborhood markers to map
label = 'South End'
label = folium.Popup(label, parse_html=True)
    
folium.Circle(
    [latitude, longitude],
    radius=1000,
    popup=label).add_to(map_Top_Hood)

map_Top_Hood
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
