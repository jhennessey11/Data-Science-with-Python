# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook

# %%
wb = load_workbook(filename='Boston Neighborhood Coordinates.xlsx', read_only=True)
ws = wb.active
col_names = [ws["A1"].value, ws["B1"].value, ws["C1"].value, ws["D1"].value]
header = np.array(col_names)

df = pd.DataFrame(ws.values, columns=header)
wb.close()

# %%
#df['Zip Code'] = df['Zip Code'].astype(str).str.zfill(5)
df = df.drop(['Zip Code'], axis=1)
df = df.drop([0])
df.set_index('Neighborhood', inplace=True)

# %%
df = df.dropna()

# %%
df
# Out:
#                            Latitude Longitude
# Neighborhood
# Chinatown/Leather District  42.3515  -71.0602
# West End                    42.3653  -71.0646
# Bay Village                 42.3531  -71.0765
# South End                   42.3378  -71.0706
# Roxbury                     42.3218  -71.0884
# Mission Hill                42.3319  -71.0988
# Mattapan                    42.2771  -71.0914
# South Boston                42.3365  -71.0349
# East Boston                 42.3695  -71.0201
# Charlestown                 42.3795  -71.0646
# Jamaica Plain               42.3097  -71.1151
# Roslindale                  42.2832   -71.127
# West Roxbury                42.2798  -71.1627
# Allston                     42.3593   -71.127
# Brighton                    42.3464  -71.1627
# Hyde Park                   42.2528    -71.13
# North Cambridge             42.3933  -71.1345
# Kendall Square              42.3625  -71.0805
# Brookline Village           42.3328  -71.1389
# Chestnut Hill               42.3178  -71.1627
# Downtown                    42.3573  -71.0562
# North End                   42.3646  -71.0534
# Beacon Hill                 42.3598  -71.0678
# Back Bay                    42.3515  -71.0805
# Dorchester                  42.2981  -71.0625
# Harvard Square              42.3725  -71.1202
# East Cambridge              42.3675  -71.0794
# Fenway/Kenmore              42.3441  -71.0957
# Porter Square               42.3894  -71.1194
# West Cambridge               42.377  -71.1359
# Inman Square                42.3734  -71.0982
# Central Square              42.3651  -71.1034
# Davis Square                42.3963  -71.1222
# Winter Hill                 42.3909  -71.0958
# Assembly Square             42.3931  -71.0804
# Seaport                     42.3492  -71.0415

# %%
import folium # map rendering library

# %%
# create map of New York using latitude and longitude values
map_Boston = folium.Map(location=[42.3261, -71.07], zoom_start=12)

# add markers to map
for lat, lng, neighborhood in zip(df['Latitude'], df['Longitude'], df.index):
    label = f'{neighborhood}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Boston)  
    
map_Boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests
import json # library to handle JSON files

# %%
CLIENT_ID = 'GKVJ5KSFU1RD00P24CV5JT2XSARMWSONFYRMLT2EK2IJFEBW' # your Foursquare ID
CLIENT_SECRET = 'SSJALJ4S5QXDNQBZMNUNFBE1XMVQZETMJWU1JDXE2VWK2PZL' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
hood_name = 'West End'
hood_lat = df.loc[hood_name, 'Latitude'] # neighborhood latitude value
hood_long = df.loc[hood_name, 'Longitude'] # neighborhood longitude value
radius = 500
LIMIT = 100

url = f'https://api.foursquare.com/v2/venues/explore?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&ll={hood_lat},{hood_long}&v={VERSION}&radius={radius}&limit={LIMIT}'

# %%
r = requests.get(url)
r.status_code
results = r.json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = pd.json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                               name            categories        lat        lng
# 0                        TD Garden          Hockey Arena  42.366329 -71.062153
# 1     Bobby Orr Statue @ TD Garden     Outdoor Sculpture  42.365314 -71.062381
# 2                     Tasty Burger          Burger Joint  42.365738 -71.063105
# 3  The Clubs at Charles River Park  Gym / Fitness Center  42.365985 -71.068257
# 4                    J. Pace & Son         Deli / Bodega  42.364682 -71.067107

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 74 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
Boston_venues = getNearbyVenues(names=df.index, latitudes=df['Latitude'], longitudes=df['Longitude'])
# Out:
# Chinatown/Leather District
# West End
# Bay Village
# South End
# Roxbury
# Mission Hill
# Mattapan
# South Boston
# East Boston
# Charlestown
# Jamaica Plain
# Roslindale
# West Roxbury
# Allston
# Brighton
# Hyde Park
# North Cambridge
# Kendall Square
# Brookline Village
# Chestnut Hill
# Downtown
# North End
# Beacon Hill
# Back Bay
# Dorchester
# Harvard Square
# East Cambridge
# Fenway/Kenmore
# Porter Square
# West Cambridge
# Inman Square
# Central Square
# Davis Square
# Winter Hill
# Assembly Square
# Seaport

# %%
print(Boston_venues.shape)
    
Boston_venues.nunique()
# Out:
# (1396, 7)
# Neighborhood                36
# Neighborhood Latitude       36
# Neighborhood Longitude      32
# Venue                     1169
# Venue Latitude            1318
# Venue Longitude           1319
# Venue Category             248
# dtype: int64

# %%
Boston_venues.head()
# Out:
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Chinatown/Leather District                42.3515                -71.0602
# 1  Chinatown/Leather District                42.3515                -71.0602
# 2  Chinatown/Leather District                42.3515                -71.0602
# 3  Chinatown/Leather District                42.3515                -71.0602
# 4  Chinatown/Leather District                42.3515                -71.0602
#
#                              Venue  Venue Latitude  Venue Longitude  \
# 0                 Gracenote Coffee       42.351657       -71.058204
# 1                        Shabu Zen       42.350922       -71.060942
# 2          Crave - Mad for Chicken       42.350378       -71.060786
# 3                            Shojo       42.351028       -71.060736
# 4  Hostelling International Boston       42.351084       -71.063398
#
#       Venue Category
# 0        Coffee Shop
# 1   Asian Restaurant
# 2  Korean Restaurant
# 3   Asian Restaurant
# 4             Hostel

# %%
Venue_cat_count = Boston_venues.groupby('Venue Category').count()
Venue_cat_count.rename(columns={'Venue': 'Count'}, inplace=True)
Venue_cat_count = pd.DataFrame(Venue_cat_count['Count'], Venue_cat_count.index)
Venue_cat_count
# Out:
#                     Count
# Venue Category
# Accessories Store       3
# Afghan Restaurant       2
# African Restaurant      1
# Airport                 1
# Airport Lounge          3
# ...                   ...
# Wine Bar                9
# Wine Shop               3
# Wings Joint             1
# Women's Store           4
# Yoga Studio            13
#
# [248 rows x 1 columns]

# %%
Venue_cat_count.to_excel('Venue_Category_Counts.xlsx')

# %%
Venue_per_hood = Boston_venues.groupby('Neighborhood').count()
Venue_per_hood.rename(columns={'Venue': 'Count'}, inplace=True)
Venue_per_hood = pd.DataFrame(Venue_per_hood['Count'], Venue_per_hood.index)
Venue_per_hood
# Out:
#                             Count
# Neighborhood
# Allston                        10
# Assembly Square                83
# Back Bay                       56
# Bay Village                    50
# Beacon Hill                    39
# Brighton                       13
# Brookline Village               3
# Central Square                 38
# Charlestown                    25
# Chestnut Hill                   2
# Chinatown/Leather District    100
# Davis Square                   55
# Dorchester                     26
# Downtown                       52
# East Boston                    38
# East Cambridge                 54
# Fenway/Kenmore                 81
# Harvard Square                100
# Hyde Park                       8
# Inman Square                   45
# Jamaica Plain                  38
# Kendall Square                 43
# Mattapan                        2
# Mission Hill                   32
# North Cambridge                13
# North End                      69
# Porter Square                  58
# Roslindale                     23
# Roxbury                         2
# Seaport                        57
# South Boston                   36
# South End                      32
# West Cambridge                  5
# West End                       74
# West Roxbury                   14
# Winter Hill                    20

# %%
# one hot encoding
Boston_onehot = pd.get_dummies(Boston_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Boston_onehot['Neighborhood'] = Boston_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [Boston_onehot.columns[-1]] + list(Boston_onehot.columns[:-1])
Boston_onehot = Boston_onehot[fixed_columns]

Totals = Boston_onehot.sum()
Totals = pd.DataFrame(Totals)
Totals = Totals.drop('Neighborhood')
Totals.rename(columns={0: 'Totals'}, inplace=True)

# %%
Boston_grouped = Boston_onehot.groupby('Neighborhood').mean().reset_index()
Boston_grouped
# Out:
#                   Neighborhood  Yoga Studio  Accessories Store  \
# 0                      Allston     0.000000           0.000000
# 1              Assembly Square     0.000000           0.000000
# 2                     Back Bay     0.017857           0.000000
# 3                  Bay Village     0.000000           0.020000
# 4                  Beacon Hill     0.025641           0.000000
# 5                     Brighton     0.000000           0.000000
# 6            Brookline Village     0.000000           0.000000
# 7               Central Square     0.026316           0.000000
# 8                  Charlestown     0.040000           0.000000
# 9                Chestnut Hill     0.000000           0.000000
# 10  Chinatown/Leather District     0.010000           0.000000
# 11                Davis Square     0.018182           0.000000
# 12                  Dorchester     0.000000           0.000000
# 13                    Downtown     0.000000           0.000000
# 14                 East Boston     0.000000           0.000000
# 15              East Cambridge     0.000000           0.000000
# 16              Fenway/Kenmore     0.000000           0.000000
# 17             Harvard Square      0.000000           0.000000
# 18                   Hyde Park     0.125000           0.000000
# 19                Inman Square     0.000000           0.000000
# 20               Jamaica Plain     0.052632           0.052632
# 21              Kendall Square     0.000000           0.000000
# 22                    Mattapan     0.000000           0.000000
# 23                Mission Hill     0.000000           0.000000
# 24            North Cambridge      0.076923           0.000000
# 25                   North End     0.014493           0.000000
# 26               Porter Square     0.000000           0.000000
# 27                  Roslindale     0.000000           0.000000
# 28                     Roxbury     0.000000           0.000000
# 29                     Seaport     0.000000           0.000000
# 30                South Boston     0.000000           0.000000
# 31                   South End     0.031250           0.000000
# 32              West Cambridge     0.000000           0.000000
# 33                    West End     0.013514           0.000000
# 34                West Roxbury     0.000000           0.000000
# 35                 Winter Hill     0.000000           0.000000
#
#     Afghan Restaurant  African Restaurant   Airport  Airport Lounge  \
# 0            0.000000             0.00000  0.000000        0.000000
# 1            0.000000             0.00000  0.000000        0.000000
# 2            0.000000             0.00000  0.000000        0.000000
# 3            0.000000             0.00000  0.000000        0.000000
# 4            0.000000             0.00000  0.000000        0.000000
# 5            0.000000             0.00000  0.000000        0.000000
# 6            0.000000             0.00000  0.000000        0.000000
# 7            0.000000             0.00000  0.000000        0.000000
# 8            0.000000             0.00000  0.000000        0.000000
# 9            0.000000             0.00000  0.000000        0.000000
# 10           0.000000             0.00000  0.000000        0.000000
# 11           0.000000             0.00000  0.000000        0.000000
# 12           0.000000             0.00000  0.000000        0.000000
# 13           0.000000             0.00000  0.000000        0.000000
# 14           0.000000             0.00000  0.026316        0.078947
# 15           0.018519             0.00000  0.000000        0.000000
# 16           0.000000             0.00000  0.000000        0.000000
# 17           0.000000             0.00000  0.000000        0.000000
# 18           0.000000             0.00000  0.000000        0.000000
# 19           0.000000             0.00000  0.000000        0.000000
# 20           0.000000             0.00000  0.000000        0.000000
# 21           0.023256             0.00000  0.000000        0.000000
# 22           0.000000             0.00000  0.000000        0.000000
# 23           0.000000             0.03125  0.000000        0.000000
# 24           0.000000             0.00000  0.000000        0.000000
# 25           0.000000             0.00000  0.000000        0.000000
# 26           0.000000             0.00000  0.000000        0.000000
# 27           0.000000             0.00000  0.000000        0.000000
# 28           0.000000             0.00000  0.000000        0.000000
# 29           0.000000             0.00000  0.000000        0.000000
# 30           0.000000             0.00000  0.000000        0.000000
# 31           0.000000             0.00000  0.000000        0.000000
# 32           0.000000             0.00000  0.000000        0.000000
# 33           0.000000             0.00000  0.000000        0.000000
# 34           0.000000             0.00000  0.000000        0.000000
# 35           0.000000             0.00000  0.000000        0.000000
#
#     Airport Service  American Restaurant  Antique Shop  ...  \
# 0          0.000000             0.000000      0.000000  ...
# 1          0.000000             0.024096      0.000000  ...
# 2          0.000000             0.035714      0.000000  ...
# 3          0.000000             0.040000      0.000000  ...
# 4          0.000000             0.025641      0.000000  ...
# 5          0.000000             0.000000      0.000000  ...
# 6          0.000000             0.000000      0.000000  ...
# 7          0.000000             0.026316      0.000000  ...
# 8          0.000000             0.040000      0.000000  ...
# 9          0.000000             0.000000      0.000000  ...
# 10         0.000000             0.010000      0.000000  ...
# 11         0.000000             0.018182      0.018182  ...
# 12         0.000000             0.000000      0.000000  ...
# 13         0.000000             0.038462      0.000000  ...
# 14         0.052632             0.052632      0.000000  ...
# 15         0.000000             0.037037      0.000000  ...
# 16         0.000000             0.049383      0.000000  ...
# 17         0.000000             0.040000      0.000000  ...
# 18         0.000000             0.000000      0.000000  ...
# 19         0.000000             0.000000      0.000000  ...
# 20         0.000000             0.026316      0.000000  ...
# 21         0.000000             0.046512      0.000000  ...
# 22         0.000000             0.000000      0.000000  ...
# 23         0.000000             0.000000      0.000000  ...
# 24         0.000000             0.000000      0.000000  ...
# 25         0.000000             0.000000      0.000000  ...
# 26         0.000000             0.017241      0.000000  ...
# 27         0.000000             0.086957      0.000000  ...
# 28         0.000000             0.000000      0.000000  ...
# 29         0.000000             0.052632      0.000000  ...
# 30         0.000000             0.027778      0.000000  ...
# 31         0.000000             0.031250      0.000000  ...
# 32         0.000000             0.200000      0.000000  ...
# 33         0.000000             0.013514      0.000000  ...
# 34         0.000000             0.000000      0.000000  ...
# 35         0.000000             0.000000      0.000000  ...
#
#     Vegetarian / Vegan Restaurant  Veterinarian  Video Game Store  \
# 0                        0.000000      0.000000          0.000000
# 1                        0.000000      0.000000          0.000000
# 2                        0.000000      0.000000          0.000000
# 3                        0.020000      0.000000          0.000000
# 4                        0.000000      0.000000          0.000000
# 5                        0.000000      0.000000          0.000000
# 6                        0.000000      0.000000          0.000000
# 7                        0.078947      0.000000          0.000000
# 8                        0.000000      0.000000          0.000000
# 9                        0.000000      0.000000          0.000000
# 10                       0.020000      0.000000          0.000000
# 11                       0.000000      0.000000          0.000000
# 12                       0.000000      0.000000          0.038462
# 13                       0.019231      0.000000          0.000000
# 14                       0.000000      0.000000          0.000000
# 15                       0.000000      0.000000          0.000000
# 16                       0.012346      0.000000          0.000000
# 17                       0.020000      0.000000          0.000000
# 18                       0.000000      0.000000          0.000000
# 19                       0.022222      0.000000          0.000000
# 20                       0.000000      0.000000          0.000000
# 21                       0.000000      0.000000          0.000000
# 22                       0.000000      0.000000          0.000000
# 23                       0.000000      0.000000          0.000000
# 24                       0.000000      0.000000          0.000000
# 25                       0.000000      0.000000          0.000000
# 26                       0.000000      0.000000          0.000000
# 27                       0.000000      0.000000          0.000000
# 28                       0.000000      0.000000          0.000000
# 29                       0.017544      0.000000          0.000000
# 30                       0.000000      0.027778          0.000000
# 31                       0.000000      0.000000          0.000000
# 32                       0.000000      0.000000          0.000000
# 33                       0.000000      0.000000          0.000000
# 34                       0.000000      0.000000          0.000000
# 35                       0.000000      0.000000          0.000000
#
#     Video Store  Vietnamese Restaurant  Whisky Bar  Wine Bar  Wine Shop  \
# 0      0.000000               0.000000    0.000000  0.000000   0.000000
# 1      0.012048               0.000000    0.000000  0.000000   0.000000
# 2      0.000000               0.000000    0.000000  0.000000   0.000000
# 3      0.000000               0.000000    0.000000  0.000000   0.000000
# 4      0.000000               0.000000    0.000000  0.000000   0.000000
# 5      0.000000               0.000000    0.000000  0.000000   0.000000
# 6      0.000000               0.000000    0.000000  0.000000   0.000000
# 7      0.000000               0.000000    0.000000  0.000000   0.000000
# 8      0.000000               0.000000    0.000000  0.000000   0.000000
# 9      0.000000               0.000000    0.000000  0.000000   0.000000
# 10     0.000000               0.010000    0.000000  0.020000   0.000000
# 11     0.000000               0.000000    0.018182  0.036364   0.000000
# 12     0.000000               0.153846    0.000000  0.000000   0.000000
# 13     0.000000               0.000000    0.000000  0.000000   0.019231
# 14     0.000000               0.000000    0.000000  0.026316   0.000000
# 15     0.000000               0.018519    0.000000  0.000000   0.000000
# 16     0.000000               0.000000    0.000000  0.012346   0.000000
# 17     0.000000               0.000000    0.000000  0.010000   0.000000
# 18     0.000000               0.000000    0.000000  0.000000   0.000000
# 19     0.000000               0.000000    0.000000  0.000000   0.022222
# 20     0.000000               0.000000    0.000000  0.000000   0.000000
# 21     0.000000               0.023256    0.000000  0.000000   0.000000
# 22     0.000000               0.000000    0.000000  0.000000   0.000000
# 23     0.000000               0.000000    0.000000  0.000000   0.000000
# 24     0.000000               0.000000    0.000000  0.000000   0.000000
# 25     0.000000               0.000000    0.000000  0.000000   0.014493
# 26     0.017241               0.000000    0.000000  0.017241   0.000000
# 27     0.000000               0.000000    0.000000  0.000000   0.000000
# 28     0.000000               0.000000    0.000000  0.000000   0.000000
# 29     0.000000               0.000000    0.000000  0.000000   0.000000
# 30     0.000000               0.000000    0.000000  0.027778   0.000000
# 31     0.000000               0.000000    0.000000  0.000000   0.000000
# 32     0.000000               0.000000    0.000000  0.000000   0.000000
# 33     0.000000               0.000000    0.000000  0.000000   0.000000
# 34     0.000000               0.000000    0.000000  0.000000   0.000000
# 35     0.000000               0.000000    0.000000  0.000000   0.000000
#
#     Wings Joint  Women's Store
# 0      0.000000       0.000000
# 1      0.000000       0.012048
# 2      0.000000       0.000000
# 3      0.000000       0.000000
# 4      0.000000       0.000000
# 5      0.076923       0.000000
# 6      0.000000       0.000000
# 7      0.000000       0.000000
# 8      0.000000       0.000000
# 9      0.000000       0.000000
# 10     0.000000       0.000000
# 11     0.000000       0.000000
# 12     0.000000       0.000000
# 13     0.000000       0.000000
# 14     0.000000       0.000000
# 15     0.000000       0.000000
# 16     0.000000       0.000000
# 17     0.000000       0.010000
# 18     0.000000       0.000000
# 19     0.000000       0.022222
# 20     0.000000       0.000000
# 21     0.000000       0.000000
# 22     0.000000       0.000000
# 23     0.000000       0.000000
# 24     0.000000       0.000000
# 25     0.000000       0.000000
# 26     0.000000       0.000000
# 27     0.000000       0.000000
# 28     0.000000       0.000000
# 29     0.000000       0.000000
# 30     0.000000       0.027778
# 31     0.000000       0.000000
# 32     0.000000       0.000000
# 33     0.000000       0.000000
# 34     0.000000       0.000000
# 35     0.000000       0.000000
#
# [36 rows x 248 columns]

# %%
num_top_venues = 10

for hood in Boston_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Boston_grouped[Boston_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Allston----
#                            venue  freq
# 0            Rental Car Location   0.2
# 1                     Donut Shop   0.2
# 2                            Gym   0.1
# 3                         Bakery   0.1
# 4              Convenience Store   0.1
# 5                    Music Venue   0.1
# 6                           Park   0.1
# 7                   Liquor Store   0.1
# 8                    Pastry Shop   0.0
# 9  Paper / Office Supplies Store   0.0
#
#
# ----Assembly Square----
#                  venue  freq
# 0       Clothing Store  0.11
# 1          Coffee Shop  0.04
# 2  Sporting Goods Shop  0.04
# 3                  Gym  0.02
# 4        Shopping Mall  0.02
# 5           Shoe Store  0.02
# 6                 Park  0.02
# 7           Kids Store  0.02
# 8     Department Store  0.02
# 9                 Bank  0.02
#
#
# ----Back Bay----
#                       venue  freq
# 0                     Hotel  0.07
# 1        Seafood Restaurant  0.05
# 2        Italian Restaurant  0.05
# 3                     Plaza  0.04
# 4                Restaurant  0.04
# 5  Mediterranean Restaurant  0.04
# 6       American Restaurant  0.04
# 7             Grocery Store  0.04
# 8               Coffee Shop  0.04
# 9            Clothing Store  0.04
#
#
# ----Bay Village----
#                  venue  freq
# 0                  Spa  0.08
# 1        Jewelry Store  0.08
# 2                 Park  0.06
# 3          Coffee Shop  0.04
# 4                Plaza  0.04
# 5  American Restaurant  0.04
# 6                Hotel  0.04
# 7       Clothing Store  0.04
# 8          Salad Place  0.04
# 9       Cosmetics Shop  0.02
#
#
# ----Beacon Hill----
#                 venue  freq
# 0         Pizza Place  0.10
# 1  Italian Restaurant  0.08
# 2          Food Truck  0.05
# 3        Gourmet Shop  0.05
# 4   French Restaurant  0.05
# 5      History Museum  0.03
# 6   Hotpot Restaurant  0.03
# 7           Hotel Bar  0.03
# 8   Other Repair Shop  0.03
# 9              Bistro  0.03
#
#
# ----Brighton----
#                 venue  freq
# 0         Pizza Place  0.23
# 1  Chinese Restaurant  0.08
# 2         Wings Joint  0.08
# 3                Park  0.08
# 4     Supplement Shop  0.08
# 5           Bookstore  0.08
# 6    Sushi Restaurant  0.08
# 7   Convenience Store  0.08
# 8   Mobile Phone Shop  0.08
# 9         Coffee Shop  0.08
#
#
# ----Brookline Village----
#               venue  freq
# 0              Lake  0.33
# 1             Plaza  0.33
# 2     Metro Station  0.33
# 3       Yoga Studio  0.00
# 4  Pedestrian Plaza  0.00
# 5         Nightclub  0.00
# 6      Noodle House  0.00
# 7       Opera House  0.00
# 8      Optical Shop  0.00
# 9   Organic Grocery  0.00
#
#
# ----Central Square----
#                            venue  freq
# 0  Vegetarian / Vegan Restaurant  0.08
# 1                            Bar  0.05
# 2                   Cocktail Bar  0.05
# 3                 Sandwich Place  0.05
# 4                    Yoga Studio  0.03
# 5           Ethiopian Restaurant  0.03
# 6               Sushi Restaurant  0.03
# 7                 Breakfast Spot  0.03
# 8                    Supermarket  0.03
# 9                    Coffee Shop  0.03
#
#
# ----Charlestown----
#                venue  freq
# 0        Coffee Shop  0.12
# 1  Convenience Store  0.08
# 2        Pizza Place  0.08
# 3        Yoga Studio  0.04
# 4          Gastropub  0.04
# 5      National Park  0.04
# 6      Grocery Store  0.04
# 7                Gym  0.04
# 8               Café  0.04
# 9       Tennis Court  0.04
#
#
# ----Chestnut Hill----
#                      venue  freq
# 0               Playground   0.5
# 1                     Park   0.5
# 2              Yoga Studio   0.0
# 3         Pedestrian Plaza   0.0
# 4  New American Restaurant   0.0
# 5                Nightclub   0.0
# 6             Noodle House   0.0
# 7              Opera House   0.0
# 8             Optical Shop   0.0
# 9          Organic Grocery   0.0
#
#
# ----Chinatown/Leather District----
#                 venue  freq
# 0  Chinese Restaurant  0.12
# 1    Asian Restaurant  0.08
# 2              Bakery  0.07
# 3         Coffee Shop  0.05
# 4    Sushi Restaurant  0.04
# 5                Café  0.03
# 6      Sandwich Place  0.03
# 7           Hotel Bar  0.03
# 8        Noodle House  0.02
# 9     Bubble Tea Shop  0.02
#
#
# ----Davis Square----
#                 venue  freq
# 0         Pizza Place  0.05
# 1  Mexican Restaurant  0.05
# 2                Café  0.05
# 3           Gift Shop  0.04
# 4                Park  0.04
# 5          Hobby Shop  0.04
# 6            Wine Bar  0.04
# 7    Ramen Restaurant  0.04
# 8        Gourmet Shop  0.04
# 9    Greek Restaurant  0.02
#
#
# ----Dorchester----
#                        venue  freq
# 0      Vietnamese Restaurant  0.15
# 1             Sandwich Place  0.08
# 2         Seafood Restaurant  0.08
# 3               Liquor Store  0.08
# 4                       Café  0.08
# 5                   Tea Room  0.04
# 6             Baseball Field  0.04
# 7       Fast Food Restaurant  0.04
# 8              Metro Station  0.04
# 9  Cajun / Creole Restaurant  0.04
#
#
# ----Downtown----
#                 venue  freq
# 0       Historic Site  0.08
# 1               Hotel  0.08
# 2      Sandwich Place  0.06
# 3                Park  0.06
# 4         Coffee Shop  0.06
# 5  Italian Restaurant  0.04
# 6         Salad Place  0.04
# 7              Bakery  0.04
# 8    Greek Restaurant  0.04
# 9          Steakhouse  0.04
#
#
# ----East Boston----
#                  venue  freq
# 0           Donut Shop  0.21
# 1          Coffee Shop  0.11
# 2       Airport Lounge  0.08
# 3                Hotel  0.05
# 4      Airport Service  0.05
# 5  American Restaurant  0.05
# 6    Electronics Store  0.05
# 7                 Café  0.05
# 8         Burger Joint  0.03
# 9       Sandwich Place  0.03
#
#
# ----East Cambridge----
#                   venue  freq
# 0                  Café  0.06
# 1        Sandwich Place  0.06
# 2                 Hotel  0.04
# 3           Pizza Place  0.04
# 4            Food Truck  0.04
# 5        Cosmetics Shop  0.04
# 6  Gym / Fitness Center  0.04
# 7           Coffee Shop  0.04
# 8   American Restaurant  0.04
# 9        Lingerie Store  0.04
#
#
# ----Fenway/Kenmore----
#                  venue  freq
# 0           Sports Bar  0.06
# 1          Pizza Place  0.05
# 2               Lounge  0.05
# 3          Coffee Shop  0.05
# 4  American Restaurant  0.05
# 5      Thai Restaurant  0.04
# 6           Restaurant  0.04
# 7        Hot Dog Joint  0.02
# 8                 Café  0.02
# 9     Greek Restaurant  0.02
#
#
# ----Harvard Square ----
#                  venue  freq
# 0            Bookstore  0.07
# 1                 Café  0.06
# 2          Pizza Place  0.05
# 3  American Restaurant  0.04
# 4                Plaza  0.03
# 5                  Spa  0.03
# 6         Burger Joint  0.03
# 7            Gastropub  0.03
# 8          Record Shop  0.03
# 9       Ice Cream Shop  0.03
#
#
# ----Hyde Park----
#                   venue  freq
# 0           Yoga Studio  0.12
# 1            Skate Park  0.12
# 2                  Park  0.12
# 3              Pharmacy  0.12
# 4                  Bank  0.12
# 5  Fast Food Restaurant  0.12
# 6        Clothing Store  0.12
# 7         Grocery Store  0.12
# 8     Outdoor Sculpture  0.00
# 9          Outlet Store  0.00
#
#
# ----Inman Square----
#                       venue  freq
# 0                       Bar  0.07
# 1   New American Restaurant  0.04
# 2  Mediterranean Restaurant  0.04
# 3             Women's Store  0.02
# 4     Portuguese Restaurant  0.02
# 5                       Pub  0.02
# 6                Donut Shop  0.02
# 7            Discount Store  0.02
# 8                     Diner  0.02
# 9            Sandwich Place  0.02
#
#
# ----Jamaica Plain----
#                     venue  freq
# 0                  Bakery  0.08
# 1             Yoga Studio  0.05
# 2       Accessories Store  0.05
# 3             Pizza Place  0.05
# 4  Thrift / Vintage Store  0.05
# 5             Coffee Shop  0.05
# 6             Art Gallery  0.05
# 7              Taco Place  0.03
# 8               Pet Store  0.03
# 9                Pharmacy  0.03
#
#
# ----Kendall Square----
#                       venue  freq
# 0                      Café  0.07
# 1            Ice Cream Shop  0.05
# 2       American Restaurant  0.05
# 3                 Hotel Bar  0.05
# 4                Food Truck  0.05
# 5               Coffee Shop  0.05
# 6   New American Restaurant  0.05
# 7  Mediterranean Restaurant  0.05
# 8                       Gym  0.05
# 9            Sandwich Place  0.05
#
#
# ----Mattapan----
#                      venue  freq
# 0           Ice Cream Shop   0.5
# 1              Pizza Place   0.5
# 2              Yoga Studio   0.0
# 3         Pedestrian Plaza   0.0
# 4  New American Restaurant   0.0
# 5                Nightclub   0.0
# 6             Noodle House   0.0
# 7              Opera House   0.0
# 8             Optical Shop   0.0
# 9          Organic Grocery   0.0
#
#
# ----Mission Hill----
#                       venue  freq
# 0               Pizza Place  0.12
# 1                Donut Shop  0.09
# 2                       Gym  0.06
# 3              Liquor Store  0.06
# 4                 Gastropub  0.03
# 5  Bike Rental / Bike Share  0.03
# 6      Gym / Fitness Center  0.03
# 7          Sushi Restaurant  0.03
# 8               Supermarket  0.03
# 9   New American Restaurant  0.03
#
#
# ----North Cambridge ----
#                       venue  freq
# 0             Movie Theater  0.15
# 1            Baseball Field  0.15
# 2               Yoga Studio  0.08
# 3              Home Service  0.08
# 4                     Track  0.08
# 5             Grocery Store  0.08
# 6        Mexican Restaurant  0.08
# 7  Bike Rental / Bike Share  0.08
# 8                   Dog Run  0.08
# 9             Moving Target  0.08
#
#
# ----North End----
#                 venue  freq
# 0  Italian Restaurant  0.14
# 1  Seafood Restaurant  0.09
# 2                Park  0.09
# 3              Bakery  0.07
# 4         Pizza Place  0.07
# 5      Sandwich Place  0.04
# 6            Boutique  0.03
# 7     Harbor / Marina  0.03
# 8        Concert Hall  0.01
# 9  Salon / Barbershop  0.01
#
#
# ----Porter Square----
#                  venue  freq
# 0  Japanese Restaurant  0.09
# 1                  Spa  0.05
# 2     Toy / Game Store  0.03
# 3      Thai Restaurant  0.03
# 4    Indian Restaurant  0.03
# 5                 Café  0.03
# 6                  Bar  0.03
# 7        Shopping Mall  0.03
# 8  Arts & Crafts Store  0.03
# 9          Coffee Shop  0.03
#
#
# ----Roslindale----
#                  venue  freq
# 0  American Restaurant  0.09
# 1   Italian Restaurant  0.09
# 2       Ice Cream Shop  0.04
# 3     Greek Restaurant  0.04
# 4               Bakery  0.04
# 5             Pharmacy  0.04
# 6        Grocery Store  0.04
# 7          Coffee Shop  0.04
# 8          Pizza Place  0.04
# 9       Sandwich Place  0.04
#
#
# ----Roxbury----
#                      venue  freq
# 0        Convenience Store   0.5
# 1                     Park   0.5
# 2              Yoga Studio   0.0
# 3    Performing Arts Venue   0.0
# 4  New American Restaurant   0.0
# 5                Nightclub   0.0
# 6             Noodle House   0.0
# 7              Opera House   0.0
# 8             Optical Shop   0.0
# 9          Organic Grocery   0.0
#
#
# ----Seaport----
#                  venue  freq
# 0   Seafood Restaurant  0.12
# 1                 Café  0.05
# 2           Donut Shop  0.05
# 3           Steakhouse  0.05
# 4  American Restaurant  0.05
# 5        Deli / Bodega  0.04
# 6   Mexican Restaurant  0.04
# 7           Restaurant  0.04
# 8                Hotel  0.04
# 9           Art Museum  0.04
#
#
# ----South Boston----
#                      venue  freq
# 0                      Bar  0.08
# 1        Convenience Store  0.08
# 2                 Dive Bar  0.06
# 3  New American Restaurant  0.06
# 4                    Diner  0.06
# 5              Coffee Shop  0.06
# 6           Breakfast Spot  0.06
# 7                     Café  0.03
# 8                      Gym  0.03
# 9             Gourmet Shop  0.03
#
#
# ----South End----
#                       venue  freq
# 0                     Diner  0.06
# 1  Mediterranean Restaurant  0.06
# 2            Sandwich Place  0.06
# 3                      Café  0.06
# 4      Gym / Fitness Center  0.03
# 5            Breakfast Spot  0.03
# 6          Greek Restaurant  0.03
# 7                 Gastropub  0.03
# 8                      Park  0.03
# 9      Cambodian Restaurant  0.03
#
#
# ----West Cambridge----
#                    venue  freq
# 0              Pet Store   0.2
# 1    American Restaurant   0.2
# 2               Bus Line   0.2
# 3               Bus Stop   0.2
# 4                   Park   0.2
# 5  Performing Arts Venue   0.0
# 6           Noodle House   0.0
# 7            Opera House   0.0
# 8           Optical Shop   0.0
# 9        Organic Grocery   0.0
#
#
# ----West End----
#                  venue  freq
# 0                Hotel  0.07
# 1       Sandwich Place  0.07
# 2           Donut Shop  0.05
# 3                  Bar  0.05
# 4          Coffee Shop  0.05
# 5          Pizza Place  0.04
# 6           Sports Bar  0.04
# 7                  Gym  0.03
# 8    Convenience Store  0.03
# 9  Sporting Goods Shop  0.03
#
#
# ----West Roxbury----
#                 venue  freq
# 0       Grocery Store  0.14
# 1          Donut Shop  0.14
# 2                 Pub  0.07
# 3  Salon / Barbershop  0.07
# 4                Bank  0.07
# 5            Pharmacy  0.07
# 6     Automotive Shop  0.07
# 7         Pizza Place  0.07
# 8       Train Station  0.07
# 9         Gas Station  0.07
#
#
# ----Winter Hill----
#                    venue  freq
# 0            Pizza Place  0.15
# 1           Liquor Store  0.10
# 2      Convenience Store  0.10
# 3  General Entertainment  0.05
# 4         Sandwich Place  0.05
# 5               Bus Stop  0.05
# 6            Music Venue  0.05
# 7                   Café  0.05
# 8   Gym / Fitness Center  0.05
# 9                   Bank  0.05

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Boston_grouped['Neighborhood']

for ind in np.arange(Boston_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Boston_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                   Neighborhood          1st Most Common Venue  \
# 0                      Allston                     Donut Shop
# 1              Assembly Square                 Clothing Store
# 2                     Back Bay                          Hotel
# 3                  Bay Village                            Spa
# 4                  Beacon Hill                    Pizza Place
# 5                     Brighton                    Pizza Place
# 6            Brookline Village                           Lake
# 7               Central Square  Vegetarian / Vegan Restaurant
# 8                  Charlestown                    Coffee Shop
# 9                Chestnut Hill                     Playground
# 10  Chinatown/Leather District             Chinese Restaurant
# 11                Davis Square             Mexican Restaurant
# 12                  Dorchester          Vietnamese Restaurant
# 13                    Downtown                          Hotel
# 14                 East Boston                     Donut Shop
# 15              East Cambridge                           Café
# 16              Fenway/Kenmore                     Sports Bar
# 17             Harvard Square                       Bookstore
# 18                   Hyde Park                    Yoga Studio
# 19                Inman Square                            Bar
# 20               Jamaica Plain                         Bakery
# 21              Kendall Square                           Café
# 22                    Mattapan                 Ice Cream Shop
# 23                Mission Hill                    Pizza Place
# 24            North Cambridge                   Movie Theater
# 25                   North End             Italian Restaurant
# 26               Porter Square            Japanese Restaurant
# 27                  Roslindale             Italian Restaurant
# 28                     Roxbury              Convenience Store
# 29                     Seaport             Seafood Restaurant
# 30                South Boston              Convenience Store
# 31                   South End                 Sandwich Place
# 32              West Cambridge                           Park
# 33                    West End                 Sandwich Place
# 34                West Roxbury                     Donut Shop
# 35                 Winter Hill                    Pizza Place
#
#        2nd Most Common Venue     3rd Most Common Venue  \
# 0        Rental Car Location              Liquor Store
# 1                Coffee Shop       Sporting Goods Shop
# 2         Seafood Restaurant        Italian Restaurant
# 3              Jewelry Store                      Park
# 4         Italian Restaurant         French Restaurant
# 5            Supplement Shop        Chinese Restaurant
# 6                      Plaza             Metro Station
# 7               Cocktail Bar            Sandwich Place
# 8          Convenience Store               Pizza Place
# 9                       Park             Women's Store
# 10          Asian Restaurant                    Bakery
# 11                      Café               Pizza Place
# 12        Seafood Restaurant            Sandwich Place
# 13             Historic Site               Coffee Shop
# 14               Coffee Shop            Airport Lounge
# 15            Sandwich Place                     Hotel
# 16                    Lounge               Pizza Place
# 17                      Café               Pizza Place
# 18            Clothing Store      Fast Food Restaurant
# 19   New American Restaurant  Mediterranean Restaurant
# 20               Coffee Shop    Thrift / Vintage Store
# 21   New American Restaurant                       Gym
# 22               Pizza Place             Women's Store
# 23                Donut Shop              Liquor Store
# 24            Baseball Field               Yoga Studio
# 25                      Park        Seafood Restaurant
# 26                       Spa                 Bookstore
# 27       American Restaurant                       Pub
# 28                      Park            Duty-free Shop
# 29                Steakhouse                      Café
# 30                       Bar                     Diner
# 31  Mediterranean Restaurant                     Diner
# 32                 Pet Store                  Bus Stop
# 33                     Hotel               Coffee Shop
# 34             Grocery Store                       Pub
# 35              Liquor Store         Convenience Store
#
#        4th Most Common Venue   5th Most Common Venue  \
# 0                     Bakery                     Gym
# 1                Pizza Place        Department Store
# 2             Ice Cream Shop           Grocery Store
# 3        American Restaurant                   Plaza
# 4               Gourmet Shop              Food Truck
# 5                  Bookstore       Convenience Store
# 6              Women's Store    Ethiopian Restaurant
# 7                        Bar               Nightclub
# 8            Thai Restaurant                    Bank
# 9                 Donut Shop              Food Court
# 10               Coffee Shop        Sushi Restaurant
# 11                      Park               Gift Shop
# 12                      Café            Liquor Store
# 13            Sandwich Place                    Park
# 14       American Restaurant       Electronics Store
# 15               Coffee Shop          Lingerie Store
# 16       American Restaurant             Coffee Shop
# 17       American Restaurant          Ice Cream Shop
# 18                      Bank              Skate Park
# 19             Women's Store             Coffee Shop
# 20               Art Gallery             Yoga Studio
# 21  Mediterranean Restaurant              Food Truck
# 22                Donut Shop              Food Court
# 23                       Gym  Furniture / Home Store
# 24             Moving Target                    Pool
# 25               Pizza Place                  Bakery
# 26                       Bar                    Café
# 27               Pizza Place             Cheese Shop
# 28                Food Truck              Food Court
# 29                Donut Shop     American Restaurant
# 30            Breakfast Spot             Coffee Shop
# 31                      Café    Cambodian Restaurant
# 32                  Bus Line     American Restaurant
# 33                Donut Shop                     Bar
# 34             Train Station             Pizza Place
# 35      Gym / Fitness Center                 Brewery
#
#        6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                       Park     Convenience Store           Music Venue
# 1                        Gym            Kids Store         Shopping Mall
# 2   Mediterranean Restaurant           Coffee Shop        Clothing Store
# 3                Coffee Shop        Clothing Store           Salad Place
# 4                Yoga Studio        Breakfast Spot         Burrito Place
# 5                Wings Joint           Coffee Shop     Mobile Phone Shop
# 6                Event Space    Falafel Restaurant        Farmers Market
# 7                Supermarket             Bookstore        Breakfast Spot
# 8              Shopping Mall                  Café                  Pool
# 9          Food & Drink Shop                  Food           Flower Shop
# 10            Sandwich Place             Hotel Bar                  Café
# 11              Gourmet Shop      Ramen Restaurant              Wine Bar
# 12               Pizza Place        Discount Store  Fast Food Restaurant
# 13                Steakhouse                Bakery      Greek Restaurant
# 14           Airport Service                  Café                 Hotel
# 15                Food Truck  Gym / Fitness Center   American Restaurant
# 16           Thai Restaurant            Restaurant            Donut Shop
# 17               Record Shop                   Spa                 Plaza
# 18             Grocery Store              Pharmacy                  Park
# 19                      Park              Pharmacy           Pizza Place
# 20         Accessories Store           Pizza Place         Deli / Bodega
# 21            Sandwich Place   American Restaurant        Ice Cream Shop
# 22         Food & Drink Shop                  Food           Flower Shop
# 23                       Bar             Gastropub      Sushi Restaurant
# 24  Bike Rental / Bike Share               Dog Run         Grocery Store
# 25            Sandwich Place              Boutique       Harbor / Marina
# 26           Thai Restaurant     Indian Restaurant         Shopping Mall
# 27            Sandwich Place    Chinese Restaurant            Restaurant
# 28         Food & Drink Shop                  Food           Flower Shop
# 29               Music Venue            Restaurant                 Hotel
# 30   New American Restaurant              Dive Bar              Pharmacy
# 31          Sushi Restaurant    Mexican Restaurant     French Restaurant
# 32               Flower Shop           Flea Market  Fast Food Restaurant
# 33               Pizza Place            Sports Bar               Brewery
# 34                  Pharmacy    Salon / Barbershop           Gas Station
# 35        Falafel Restaurant              Bus Stop       Meze Restaurant
#
#        9th Most Common Venue         10th Most Common Venue
# 0               Dessert Shop                     Food Court
# 1                 Shoe Store            American Restaurant
# 2                 Restaurant                          Plaza
# 3                      Hotel  Vegetarian / Vegan Restaurant
# 4                       Café                     Restaurant
# 5                       Park               Sushi Restaurant
# 6       Fast Food Restaurant                    Flea Market
# 7        Shanghai Restaurant                      Rock Club
# 8                   Pharmacy                      Pet Store
# 9                Flea Market           Fast Food Restaurant
# 10                       Spa                   Dessert Shop
# 11                Hobby Shop                 Sandwich Place
# 12               Supermarket                  Metro Station
# 13       American Restaurant                    Salad Place
# 14               Bus Station                        Brewery
# 15  Mediterranean Restaurant                           Park
# 16          Greek Restaurant            Japanese Restaurant
# 17                 Gastropub                   Burger Joint
# 18              Dessert Shop                   Dance Studio
# 19   Comfort Food Restaurant          Portuguese Restaurant
# 20        Miscellaneous Shop                     Taco Place
# 21                 Hotel Bar                    Coffee Shop
# 22               Flea Market           Fast Food Restaurant
# 23               Supermarket       Bike Rental / Bike Share
# 24              Home Service             Mexican Restaurant
# 25                      Café                     Sports Bar
# 26       Arts & Crafts Store               Toy / Game Store
# 27               Coffee Shop              Indian Restaurant
# 28               Flea Market           Fast Food Restaurant
# 29             Deli / Bodega                    Coffee Shop
# 30            Shipping Store                           Café
# 31                Food Court                 Breakfast Spot
# 32            Duty-free Shop                 Farmers Market
# 33        Mexican Restaurant                           Café
# 34                      Bank                Automotive Shop
# 35                      Café          General Entertainment

# %%
criterion = 'Pizza'
mask = neighborhoods_venues_sorted.applymap(lambda x: criterion in str(x))
search_results = neighborhoods_venues_sorted[mask == True].dropna(how='all')
#search_results.fillna('', inplace=True)

i=0
for items in zip(search_results['Neighborhood']):
    i=i+1

#print(f"{i} Results Found!")
results = search_results.iloc[1,].unique()
match.insert(0, results[1])

# %%
def df_style(val):
    boolean = 0
    item = match[0]
    if val == item:
        boolean = 1
    item = match[1]
    if val == item:
        boolean = 1
    item = match[2]
    if val == item:
        boolean = 1
        
    if boolean == 1:
        return 'font-weight: bold'
    else:
        return ''

# %%
search_neigh = neighborhoods_venues_sorted.iloc[search_results.index]

search_neigh.style.applymap(df_style)
# Out:
# <style  type="text/css" >
#     #T_6889acd2_9d68_11ea_9794_d812652c170crow0_col4 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow1_col1 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow2_col1 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow3_col3 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow4_col3 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow5_col6 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow6_col3 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow7_col3 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow8_col8 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow9_col7 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow10_col2 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow11_col1 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow12_col4 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow13_col4 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow14_col6 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow15_col5 {
#             font-weight:  bold;
#         }    #T_6889acd2_9d68_11ea_9794_d812652c170crow16_col1 {
#             font-weight:  bold;
#         }</style><table id="T_6889acd2_9d68_11ea_9794_d812652c170c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Neighborhood</th>        <th class="col_heading level0 col1" >1st Most Common Venue</th>        <th class="col_heading level0 col2" >2nd Most Common Venue</th>        <th class="col_heading level0 col3" >3rd Most Common Venue</th>        <th class="col_heading level0 col4" >4th Most Common Venue</th>        <th class="col_heading level0 col5" >5th Most Common Venue</th>        <th class="col_heading level0 col6" >6th Most Common Venue</th>        <th class="col_heading level0 col7" >7th Most Common Venue</th>        <th class="col_heading level0 col8" >8th Most Common Venue</th>        <th class="col_heading level0 col9" >9th Most Common Venue</th>        <th class="col_heading level0 col10" >10th Most Common Venue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6889acd2_9d68_11ea_9794_d812652c170clevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col0" class="data row0 col0" >Assembly Square</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col1" class="data row0 col1" >Clothing Store</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col2" class="data row0 col2" >Coffee Shop</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col3" class="data row0 col3" >Sporting Goods Shop</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col4" class="data row0 col4" >Pizza Place</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col5" class="data row0 col5" >Department Store</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col6" class="data row0 col6" >Gym</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col7" class="data row0 col7" >Kids Store</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col8" class="data row0 col8" >Shopping Mall</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col9" class="data row0 col9" >Shoe Store</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow0_col10" class="data row0 col10" >American Restaurant</td>
#             </tr>
#             <tr>
#                         <th id="T_6889acd2_9d68_11ea_9794_d812652c170clevel0_row1" class="row_heading level0 row1" >4</th>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col0" class="data row1 col0" >Beacon Hill</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col1" class="data row1 col1" >Pizza Place</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col2" class="data row1 col2" >Italian Restaurant</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col3" class="data row1 col3" >French Restaurant</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col4" class="data row1 col4" >Gourmet Shop</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col5" class="data row1 col5" >Food Truck</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col6" class="data row1 col6" >Yoga Studio</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col7" class="data row1 col7" >Breakfast Spot</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col8" class="data row1 col8" >Burrito Place</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col9" class="data row1 col9" >Café</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow1_col10" class="data row1 col10" >Restaurant</td>
#             </tr>
#             <tr>
#                         <th id="T_6889acd2_9d68_11ea_9794_d812652c170clevel0_row2" class="row_heading level0 row2" >5</th>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col0" class="data row2 col0" >Brighton</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col1" class="data row2 col1" >Pizza Place</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col2" class="data row2 col2" >Supplement Shop</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col3" class="data row2 col3" >Chinese Restaurant</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col4" class="data row2 col4" >Bookstore</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col5" class="data row2 col5" >Convenience Store</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col6" class="data row2 col6" >Wings Joint</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col7" class="data row2 col7" >Coffee Shop</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col8" class="data row2 col8" >Mobile Phone Shop</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col9" class="data row2 col9" >Park</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow2_col10" class="data row2 col10" >Sushi Restaurant</td>
#             </tr>
#             <tr>
#                         <th id="T_6889acd2_9d68_11ea_9794_d812652c170clevel0_row3" class="row_heading level0 row3" >8</th>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow3_col0" class="data row3 col0" >Charlestown</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow3_col1" class="data row3 col1" >Coffee Shop</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow3_col2" class="data row3 col2" >Convenience Store</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow3_col3" class="data row3 col3" >Pizza Place</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow3_col4" class="data row3 col4" >Thai Restaurant</td>
#                         <td id="T_6889acd2_9d68_11ea_9794_d812652c170crow3_col5" class="data row3 col5" >B

# %%
criterion = 'Sports'
mask = search_neigh.applymap(lambda x: criterion in str(x))
search_results_2 = search_neigh[mask == True].dropna(how='all')
search_results_2.fillna('', inplace=True)

i=0
for items in zip(search_results_2['Neighborhood']):
    i=i+1

print(f"{i} Results Found!")

results = search_results_2.iloc[1,].unique()
match.insert(0, results[1])
# Out:
# 3 Results Found!

# %%
search_neigh_2 = neighborhoods_venues_sorted.iloc[search_results_2.index]
search_neigh_2.style.applymap(df_style)
# Out:
# <style  type="text/css" >
#     #T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col1 {
#             font-weight:  bold;
#         }    #T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col3 {
#             font-weight:  bold;
#         }    #T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col4 {
#             font-weight:  bold;
#         }    #T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col10 {
#             font-weight:  bold;
#         }    #T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col6 {
#             font-weight:  bold;
#         }    #T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col7 {
#             font-weight:  bold;
#         }</style><table id="T_6931ae18_9d68_11ea_a0ad_d812652c170c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Neighborhood</th>        <th class="col_heading level0 col1" >1st Most Common Venue</th>        <th class="col_heading level0 col2" >2nd Most Common Venue</th>        <th class="col_heading level0 col3" >3rd Most Common Venue</th>        <th class="col_heading level0 col4" >4th Most Common Venue</th>        <th class="col_heading level0 col5" >5th Most Common Venue</th>        <th class="col_heading level0 col6" >6th Most Common Venue</th>        <th class="col_heading level0 col7" >7th Most Common Venue</th>        <th class="col_heading level0 col8" >8th Most Common Venue</th>        <th class="col_heading level0 col9" >9th Most Common Venue</th>        <th class="col_heading level0 col10" >10th Most Common Venue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6931ae18_9d68_11ea_a0ad_d812652c170clevel0_row0" class="row_heading level0 row0" >16</th>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col0" class="data row0 col0" >Fenway/Kenmore</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col1" class="data row0 col1" >Sports Bar</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col2" class="data row0 col2" >Lounge</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col3" class="data row0 col3" >Pizza Place</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col4" class="data row0 col4" >American Restaurant</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col5" class="data row0 col5" >Coffee Shop</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col6" class="data row0 col6" >Thai Restaurant</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col7" class="data row0 col7" >Restaurant</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col8" class="data row0 col8" >Donut Shop</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col9" class="data row0 col9" >Greek Restaurant</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow0_col10" class="data row0 col10" >Japanese Restaurant</td>
#             </tr>
#             <tr>
#                         <th id="T_6931ae18_9d68_11ea_a0ad_d812652c170clevel0_row1" class="row_heading level0 row1" >25</th>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col0" class="data row1 col0" >North End</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col1" class="data row1 col1" >Italian Restaurant</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col2" class="data row1 col2" >Park</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col3" class="data row1 col3" >Seafood Restaurant</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col4" class="data row1 col4" >Pizza Place</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col5" class="data row1 col5" >Bakery</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col6" class="data row1 col6" >Sandwich Place</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col7" class="data row1 col7" >Boutique</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col8" class="data row1 col8" >Harbor / Marina</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col9" class="data row1 col9" >Café</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow1_col10" class="data row1 col10" >Sports Bar</td>
#             </tr>
#             <tr>
#                         <th id="T_6931ae18_9d68_11ea_a0ad_d812652c170clevel0_row2" class="row_heading level0 row2" >33</th>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col0" class="data row2 col0" >West End</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col1" class="data row2 col1" >Sandwich Place</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col2" class="data row2 col2" >Hotel</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col3" class="data row2 col3" >Coffee Shop</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col4" class="data row2 col4" >Donut Shop</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col5" class="data row2 col5" >Bar</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col6" class="data row2 col6" >Pizza Place</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col7" class="data row2 col7" >Sports Bar</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col8" class="data row2 col8" >Brewery</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col9" class="data row2 col9" >Mexican Restaurant</td>
#                         <td id="T_6931ae18_9d68_11ea_a0ad_d812652c170crow2_col10" class="data row2 col10" >Café</td>
#             </tr>
#     </tbody></table>

# %%
match = ['']*3

# %%
len(match)
# Out:
# 3
